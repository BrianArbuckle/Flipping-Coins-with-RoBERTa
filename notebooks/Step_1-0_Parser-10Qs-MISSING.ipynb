# %%
__author__ = "Brian Arbuckle, Benu Atri and Paras Jamil"
__version__ = "CS224u, Final Project 2021 v1"
__updated__ = "Mar 23, 2021, 11pmCST"

# %%
import os
import logging
from lxml import etree
import re
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime as dt

from parse_token_utils import create_directory, parse_fileName_vals
from filing_parsers import *

today = str(dt.today()).split(' ')[0]
today
# Out:
# '2021-03-25'

# %% [markdown]
# <div class="alert alert-info">
#     <b>At some point</b><br> We will need to define what the labels are '1's and '0's as the discrepancy between performance_earnings and performance_filing this is true for about 10% - this is related to our hypothesis, the text that we need to show that it changes sentiment

# %%
## copied & adapted from data-engineering/parsers/filing_parsers.py (git)
forms = ['10-K']
def quick_parse(filepath):
    parser = etree.XMLParser(recover=True, huge_tree=True)
    tree = etree.parse(filepath, parser)
    notags = etree.tostring(tree, encoding='utf8', method='text')
    return notags
def parse_10q(filepath, cik, year):
    """
    Parses the 10-Q passed. Returns a dictionary:
        body: The body of the 10-Q
    :param filepath:
    :return:
    """
    from bs4 import BeautifulSoup
    results = {}
    with open(filepath) as fp:
        soup = BeautifulSoup(fp, "lxml")

    #results['TenKText'] = __extract_document_text(soup)
    results['headers'] = __parse_sec_header(soup, cik, year)
    results['documents'] = __parse_documents(soup)
    return results

def get_date(filingPath):
    """From FinBert"""
    #print(filingPath)
    accession_code = filingPath.split('/')[-2]
    ticker = filingPath.split('/')[-4]
    filing_type = filingPath.split('/')[-3]
    #print(accession_code, ticker, filing_type)
    code = accession_code+'.txt'
    with open(filingPath, 'r') as f:
        readlin = f.read()
    for i in readlin.split('\n'):
#         print(i)
        if code in i:
            date_extr = i.split(' : ')[1]
            return date_extr


def __parse_documents(soup):
    import time
    # Get all the douments
    result_documents = []
    documents = soup.find_all('document')

    for doc in documents:

        type_node = doc.find('type')
        if type_node:
            type_text = type_node.contents[0].strip()
            desc_node = type_node.find('description')
        else:
            type_text = 'NA'

        seq_node = doc.find('sequence')
        if seq_node:
            seq_text = seq_node.contents[0].strip()
        else:
            seq_text = str(int(time.time()))[-6:]

        if desc_node:
            desc_text = desc_node.contents[0]
        else:
            desc_text = ''

        if type_text in forms:
            is_10_q = True
        else:
            is_10_q = False

        if type_text not in ["XML", "GRAPHIC", "EXCEL", "ZIP"]:
            logging.debug("Parsing doucment type: {}".format(type_text))
            result_documents.append(
                {'is_10_q': is_10_q,
                 'type': type_text,
                 'sequence': seq_text,
                 'description': desc_text,
                 'document': __extract_document_text(soup)}
            )

    return result_documents

def __parse_sec_header(soup, cik, year):
    sec_header = soup.find("sec-header")

    if not sec_header:
        sec_header = soup

    result = {
        'cik': cik,
        'year': year,
    }
    result['accession_number'] = __get_line_item(sec_header, 'ACCESSION NUMBER:')
    result['conformed_period_of_report'] = __get_line_item(sec_header, 'CONFORMED PERIOD OF REPORT:')
    result['filed_as_of_date'] = __get_line_item(sec_header, 'FILED AS OF DATE:')
    result['company_confirmed_name'] = __get_line_item(sec_header, 'COMPANY CONFORMED NAME:')
    result['central_index_key'] = __get_line_item(sec_header, 'CENTRAL INDEX KEY:')
    result['standard_industrial_classification'] = __get_line_item(sec_header, 'STANDARD INDUSTRIAL CLASSIFICATION:')
    result['state_of_incorporation'] = __get_line_item(sec_header, 'STATE OF INCORPORATION:')
    result['fiscal_year_end'] = __get_line_item(sec_header, 'FISCAL QUARTER END:')

    return result

def __get_line_item(sec_header, attr_name):
    find_results = re.findall(attr_name + '(.*?)\n', str(sec_header))

    if find_results:
        return find_results[0].strip()
    else:
        return None
def __extract_document_text(soup):
    if len(soup) == 1:
        TenKtext = soup.find('text').extract().text
        TenKtext = parser_custom(TenKtext)
    #tables = document.find_all('table')
    #for table in tables:
    #    table.decompose()

    return TenKtext

# %%
FULL_DATASET = True
PICKLES = '../pickle_data/'
DATA = 'data'

# GLOBAL START AND END:
START = '2016-01-01'
END = '2021-03-01'

#doc_folder_name = 'item7_parsed_documents'
dataset_missing = 'needs_work/'
if FULL_DATASET == True:
    stocks_PATH = os.path.join(PICKLES, "performance_labeled.pickle")
forms = ['10-Q']

# %%
#for i in os.listdir(dataset_missing):
#    print(i)

# %%
missing_list = ["XRAY", "XEL", "ULTA", "TXN", "SWKS", "STX", "PTON"]
stocks_PATH
# Out:
# '../pickle_data/performance_labeled.pickle'

# %%
stocks_df = pd.read_pickle(stocks_PATH) 
list_of_files = ["../data/sec-edgar-filings/AMAT/10-K/0000006951-18-000041/full-submission.txt", "../data/sec-edgar-filings/AMAT/10-K/0000006951-17-000038/full-submission.txt", "../data/sec-edgar-filings/AMAT/10-K/0000006951-16-000068/full-submission.txt", "../data/sec-edgar-filings/CMCSA/10-K/0001166691-20-000008/full-submission.txt", "../data/sec-edgar-filings/CMCSA/10-K/0001166691-19-000005/full-submission.txt", "../data/sec-edgar-filings/CMCSA/10-K/0001166691-18-000004/full-submission.txt", "../data/sec-edgar-filings/CMCSA/10-K/0001193125-17-030512/full-submission.txt", "../data/sec-edgar-filings/CMCSA/10-K/0001193125-16-452423/full-submission.txt", "../data/sec-edgar-filings/EA/10-K/0000712515-20-000019/full-submission.txt", "../data/sec-edgar-filings/EA/10-K/0000712515-19-000019/full-submission.txt", "../data/sec-edgar-filings/EA/10-K/0000712515-18-000024/full-submission.txt", "../data/sec-edgar-filings/EA/10-K/0000712515-17-000035/full-submission.txt", "../data/sec-edgar-filings/EA/10-K/0000712515-16-000111/full-submission.txt", "../data/sec-edgar-filings/ILMN/10-K/0001110803-20-000018/full-submission.txt"]
stocks_df = stocks_df[stocks_df['ticker'].isin(missing_list)]

# %%
stocks_df.head()
parsed_sec_filings_path = '../data/2021-03-20_parsed_sec_filings_path/'

# %%
stocks_df.ticker.unique()
with open('failed_parser.txt', 'r') as f:
    failed_files = f.readlines()
failed_files = [x.strip() for x in failed_files]

# %%
failed_files
'''s = '/home/jovyan/work/benu_work/needs_work/ILMN/10-K/0001110803-20-000018/full-submission.txt'
print('../data/sec-edgar-filings/'+ s.split('needs_work/')[1])
'''
failed_files
# Out:
# ../data/sec-edgar-filings/ILMN/10-K/0001110803-20-000018/full-submission.txt
# ['../data/sec-edgar-filings/FAST/10-Q/0000815556-20-000056/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-20-000031/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-19-000058/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-19-000048/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-19-000027/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-18-000050/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-18-000043/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-18-000019/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-17-000045/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-17-000039/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-17-000021/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-16-000122/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-16-000113/full-submission.txt',
#  '../data/sec-edgar-filings/FAST/10-Q/0000815556-16-000097/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-20-000032/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-20-000021/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-19-000032/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-19-000023/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-19-000015/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-18-000035/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-18-000027/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-18-000016/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-17-000042/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-17-000026/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-17-000014/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-16-000038/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-16-000032/full-submission.txt',
#  '../data/sec-edgar-filings/GOOGL/10-Q/0001652044-16-000021/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-19-000067/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-19-000048/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-19-000030/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-18-000060/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-18-000039/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-17-000058/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-17-000049/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-17-000025/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-16-000102/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-16-000090/full-submission.txt',
#  '../data/sec-edgar-filings/HSIC/10-Q/0001000228-16-000066/full-submission.txt',
#  '../data/sec-edgar-filings/ILMN/10-Q/0001110803-20-000051/full-submission.txt',
#  '../data/sec-edgar-filings/ILMN/10-Q/0001110803-20-000033/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-20-000026/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-20-000017/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-19-000029/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-19-000023/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-19-000013/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-18-000029/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-18-000022/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-18-000013/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-16-000153/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-16-000142/full-submission.txt',
#  '../data/sec-edgar-filings/INTC/10-Q/0000050863-16-000125/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-20-000065/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-20-000027/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-19-000174/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-19-000077/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-19-000042/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-18-000212/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-18-000075/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-18-000036/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-17-000170/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-17-000048/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-17-000030/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-16-000316/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-16-000225/full-submission.txt',
#  '../data/sec-edgar-filings/INTU/10-Q/0000896878-16-000197/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-20-000324/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-20-000170/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-19-000273/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-19-000186/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-19-000123/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-18-000323/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-18-000229/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-18-000158/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-17-000173/full-submission.txt',
#  '../data/sec-edgar-filings/MELI/10-Q/0001562762-17-000120/full-submission.txt',
#  '../data/sec-edgar-filings/MNST/10-Q/0001104659-18-066941/full-submission.txt',
#  '../data/sec-edgar-filings/MNST/10-Q/0001104659-17-050342/full-submission.txt',
#  '../data/sec-edgar-filings/MNST/10-Q/0001104659-17-030369/full-submission.txt',
#  '../data/sec-edgar-filings/MNST/10-Q/0001104659-16-155163/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-19-000035/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-19-000014/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-18-000156/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-18-000065/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-17-000166/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-17-000085/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-17-000037/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-17-000005/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-16-000201/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-16-000176/full-submission.txt',
#  '../data/sec-edgar-filings/MU/10-Q/0000723125-16-000146/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-20-000027/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-19-000166/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-19-000127/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-19-000089/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-18-000198/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-18-000168/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-18-000103/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-17-000178/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-17-000154/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-17-000113/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-16-000385/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-16-000359/full-submission.txt',
#  '../data/sec-edgar-filings/ORLY/10-Q/0000898173-16-000311/full-submission.txt',
#  '../data/sec-edgar-filings/PAYX/10-Q/0000723531-16-000034/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-20-000134/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-20-000093/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-19-000180/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-19-000118/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-18-000203/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-18-000171/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-18-000096/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-17-000171/full-submission.txt',
#  '../data/sec-edgar-filings/PYPL/10-Q/0001633917-16-000161/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-17-000034/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-17-000030/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-17-000026/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-16-000066/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-16-000059/full-submission.txt',
#  '../data/sec-edgar-filings/ROST/10-Q/0000745732-16-000053/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-20-000066/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-20-000045/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-20-000012/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-19-000036/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-19-000024/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-19-000011/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-18-000037/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-18-000022/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-18-000009/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-17-000036/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-17-000021/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-17-000005/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-16-000074/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-16-000062/full-submission.txt',
#  '../data/sec-edgar-filings/SBUX/10-Q/0000829224-16-000049/full-submission.txt',
#  '../data/sec-edgar-filings/STX/10-Q/0001104659-16-092467/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000046/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000027/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000007/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000041/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000022/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000013/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000032/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000021/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000011/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-17-000027/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-17-000018/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-16-000062/full-submission.txt',
#  '../data/sec-edgar-filings/SWKS/10-Q/0000004127-16-000049/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0000097476-20-000026/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0000097476-20-000017/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0000097476-19-000009/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-19-027328/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-19-014051/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-18-026405/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-18-018753/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-18-010545/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-17-021032/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-17-015153/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-17-008260/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-16-027067/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-16-022552/full-submission.txt',
#  '../data/sec-edgar-filings/TXN/10-Q/0001564590-16-017570/full-submission.txt',
#  '../data/sec-edgar-filings/ULTA/10-Q/0001193125-17-191202/full-submission.txt',
#  '../data/sec-edgar-filings/XEL/10-Q/0000072903-20-000055/full-submission.txt',
#  '../data/sec-edgar-filings/XEL/10-Q/0000072903-20-000022/full-submission.txt',
#  '../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000074/full-submission.txt',
#  '../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000047/full-submission.txt',
#  '../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000019/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000042/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000035/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000019/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000031/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000025/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000012/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-16-000086/full-submission.txt',
#  '../data/sec-edgar-filings/XRAY/10-Q/0000818479-16-000081/full-submission.txt',
#  '../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000175/full-submission.txt',
#  '../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000068/full-submission.txt',
#  '../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000011/full-submission.txt',
#  '../data/sec-edgar-filings/PTON/10-Q/0001639825-19-000018/full-submission.txt',
#  '../data/sec-edgar-filings/AMAT/10-K/0000006951-18-000041/full-submission.txt',
#  '../data/sec-edgar-filings/AMAT/10-K/0000006951-17-000038/full-submission.txt',
#  '../data/sec-edgar-filings/AMAT/10-K/0000006951-16-000068/full-submission.txt',
#  '../data/sec-edgar-filings/CMCSA/10-K/0001166691-20-000008/full-submission.txt',
#  '../data/sec-edgar-filings/CMCSA/10-K/0001166691-19-000005/full-submission.txt',
#  '../data/sec-edgar-filings/CMCSA/10-K/0001166691-18-000004/full-submission.txt',
#  '../data/sec-edgar-filings/CMCSA/10-K/0001193125-17-030512/full-submission.txt',
#  '../data/sec-edgar-filings/CMCSA/10-K/0001193125-16-452423/full-submission.txt',
#  '../data/sec-edgar-filings/EA/10-K/0000712515-20-000019/full-submission.txt',
#  '../data/sec-edgar-filings/EA/10-K/0000712515-19-000019/full-submission.txt',
#  '../data/sec-edgar-filings/EA/10-K/0000712515-18-000024/full-submission.txt',
#  '../data/sec-edgar-filings/EA/10-K/0000712515-17-000035/full-submission.txt',
#  '../data/sec-edgar-filings/EA/10-K/0000712515-16-000111/full-submission.txt',
#  '../data/sec-edgar-filings/ILMN/10-K/0001110803-20-000018/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-20-000123/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-20-000087/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-20-000013/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-19-000115/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-19-000089/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-19-000013/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-18-000106/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-18-000084/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-18-000018/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-17-000114/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-17-000086/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-17-000008/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-16-000073/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-16-000067/full-submission.txt',
#  '../data/sec-edgar-filings/ADI/10-Q/0000006281-16-000060/full-submission.txt']

# %%
stocks_df.ticker.unique()
# Out:
# array(['STX', 'SWKS', 'TXN', 'ULTA', 'XEL', 'XRAY', 'PTON'], dtype=object)

# %%
from bs4 import BeautifulSoup
#create_directory(os.path.join(sec_filings_path,doc_folder_name)) #if exists, will not create again
sec_filings_path = '/home/jovyan/work/benu_work/needs_work2/'
def run_parse(stocks_df):
    num_stocks = stocks_df.shape[0]
    c = 0

    for idx, row in stocks_df.iterrows():
        if row['form'] in ['10-Q']:
            ticker_form_path = os.path.join(sec_filings_path, row['ticker'], row['form'][:4])
            
            ciks = os.listdir(ticker_form_path)
            for cik in ciks:
                if cik == '.DS_Store':
                    continue
                text_to_parse = os.path.join(ticker_form_path, cik, 'full-submission_original.txt')
                
                if os.path.exists(text_to_parse):
                    if row['date_filed'] == dt.strptime(get_date(text_to_parse), '%Y%m%d'):
                        c += 1
                        print("{:0>2d} of {} {}".format(c, num_stocks, (30*'-')))
                        ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year = parse_fileName_vals(cik, row, text_to_parse)
                        print("ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE")
                        out_file_name = ticker+'_'+cik_10dig+'_'+filing_type+'_'+filing_qrtr+ ".txt"
                        out_file_path = os.path.join(parsed_sec_filings_path, out_file_name)
                        

                        to_actually_parse = os.path.join(ticker_form_path, cik, 'full-submission.txt')

                        s = '../data/sec-edgar-filings/'+ to_actually_parse.split('needs_work2/')[1]
                        print(s)
                        print('found here', failed_files.index(s))

                        if s not in failed_files:
                            continue
                        print('FOUND IN FAILED FILES', to_actually_parse)
                        with open(to_actually_parse, 'r') as fp:
                            soup = BeautifulSoup(fp, "html.parser")
                            print(cik, len(soup))
                        
                            TenKItem7 = soup.text
                            TenKItem7 = TenKItem7.strip() # Remove starting/ending white spaces
                            TenKItem7 = TenKItem7.replace('\n', ' ') # Replace \n (new line) with space
                            TenKItem7 = TenKItem7.replace('\r', '') # Replace \r (carriage returns-if you're on windows) with space
                            TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space
                            TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space
                            TenKItem7 = TenKItem7.replace(u'/xa0', u' ') # 
                            while '  ' in TenKItem7:
                                TenKItem7 = TenKItem7.replace('  ', ' ') # Remove extra spaces



                            pattern = '0.0);text-align:right;vertical-align:bottom;padding-left:1pt;padding-right:1pt;">'

                            TenKItem7 = TenKItem7.replace(pattern, '')
                            pattern2 = r'style="line-height:120%;font-size:10pt;padding-left:0px;">'
                            #'0.0);text-align:right;vertical-align:bottom;padding-left:1pt;padding-right:1pt;">'
                            pattern3 = r'•'
                            pattern4 = 'style="background-color:rgb(255,255,255, 0.0);color:#000000;font-family:\'Arial\',sans-serif;font-size:10pt;font-weight:700;line-height:120%;">'
                            TenKItem7 = TenKItem7.replace(pattern2, '')
                            TenKItem7 = TenKItem7.replace(pattern3, '')
                            TenKItem7 = TenKItem7.replace(pattern4, '')
                            pattern5 = r'12.00pt"> '
                            TenKItem7 = TenKItem7.replace(pattern4, '')
                            pattern6 = r'style="margin-top: 0; margin-bottom: 0; text-align: left">'
                            pattern8 = r'0.0);color:#000000;font-family:\'Arial\',sans-serif;font-size:11pt;font-weight:700;line-height:120%;">'
                            pattern7 = r'style="line-height:120%;font-size:11pt;">'
                            TenKItem7 = TenKItem7.replace(pattern5, '')
                            TenKItem7 = TenKItem7.replace(pattern6, '')
                            TenKItem7 = TenKItem7.replace(pattern7, '')
                            TenKItem7 = TenKItem7.replace(pattern8, '')
                            with open(out_file_path, 'w') as f:
                                
                                f.write(TenKItem7)
                                print()
                            print(f'Parsing finished, output saved in:\n{out_file_path}')
                            print('__'*30)
                            print()
                            if c%10==0:
                                input()

run_parse(stocks_df)
# Out:
# 01 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/STX/10-Q/0001104659-16-092467/full-submission.txt
# found here 135
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/STX/10-Q/0001104659-16-092467/full-submission.txt
# 0001104659-16-092467 58
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/STX_0001104659_10-Q_Dec2015.txt
# ____________________________________________________________
#
# 02 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000046/full-submission.txt
# found here 136
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-20-000046/full-submission.txt
# 0000004127-20-000046 126
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Jun2020.txt
# ____________________________________________________________
#
# 03 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000027/full-submission.txt
# found here 137
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-20-000027/full-submission.txt
# 0000004127-20-000027 147
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Mar2020.txt
# ____________________________________________________________
#
# 04 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-20-000007/full-submission.txt
# found here 138
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-20-000007/full-submission.txt
# 0000004127-20-000007 146
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Dec2019.txt
# ____________________________________________________________
#
# 05 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000041/full-submission.txt
# found here 139
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-19-000041/full-submission.txt
# 0000004127-19-000041 156
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Jun2019.txt
# ____________________________________________________________
#
# 06 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000022/full-submission.txt
# found here 140
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-19-000022/full-submission.txt
# 0000004127-19-000022 1
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Mar2019.txt
# ____________________________________________________________
#
# 07 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-19-000013/full-submission.txt
# found here 141
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-19-000013/full-submission.txt
# 0000004127-19-000013 150
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Dec2018.txt
# ____________________________________________________________
#
# 08 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000032/full-submission.txt
# found here 142
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-18-000032/full-submission.txt
# 0000004127-18-000032 158
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Jun2018.txt
# ____________________________________________________________
#
# 09 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000021/full-submission.txt
# found here 143
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-18-000021/full-submission.txt
# 0000004127-18-000021 159
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Mar2018.txt
# ____________________________________________________________
#
# 10 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-18-000011/full-submission.txt
# found here 144
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-18-000011/full-submission.txt
# 0000004127-18-000011 188
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Dec2017.txt
# ____________________________________________________________
#
#
# 11 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-17-000027/full-submission.txt
# found here 145
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-17-000027/full-submission.txt
# 0000004127-17-000027 188
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Jun2017.txt
# ____________________________________________________________
#
# 12 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-17-000018/full-submission.txt
# found here 146
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-17-000018/full-submission.txt
# 0000004127-17-000018 184
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Mar2017.txt
# ____________________________________________________________
#
# 13 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-16-000062/full-submission.txt
# found here 147
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-16-000062/full-submission.txt
# 0000004127-16-000062 194
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Jun2016.txt
# ____________________________________________________________
#
# 14 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/SWKS/10-Q/0000004127-16-000049/full-submission.txt
# found here 148
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/SWKS/10-Q/0000004127-16-000049/full-submission.txt
# 0000004127-16-000049 201
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/SWKS_0000004127_10-Q_Mar2016.txt
# ____________________________________________________________
#
# 15 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0000097476-20-000026/full-submission.txt
# found here 149
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0000097476-20-000026/full-submission.txt
# 0000097476-20-000026 125
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0000097476_10-Q_Jun2020.txt
# ____________________________________________________________
#
# 16 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0000097476-20-000017/full-submission.txt
# found here 150
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0000097476-20-000017/full-submission.txt
# 0000097476-20-000017 96
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0000097476_10-Q_Mar2020.txt
# ____________________________________________________________
# 17 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0000097476-19-000009/full-submission.txt
# found here 151
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0000097476-19-000009/full-submission.txt
# 0000097476-19-000009 118
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0000097476_10-Q_Sep2019.txt
# ____________________________________________________________
#
# 18 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-19-027328/full-submission.txt
# found here 152
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-19-027328/full-submission.txt
# 0001564590-19-027328 213
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Jun2019.txt
# ____________________________________________________________
#
# 19 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-19-014051/full-submission.txt
# found here 153
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-19-014051/full-submission.txt
# 0001564590-19-014051 171
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Mar2019.txt
# ____________________________________________________________
#
# 20 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-18-026405/full-submission.txt
# found here 154
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-18-026405/full-submission.txt
# 0001564590-18-026405 229
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Sep2018.txt
# ____________________________________________________________
#
#
# 21 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-18-018753/full-submission.txt
# found here 155
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-18-018753/full-submission.txt
# 0001564590-18-018753 219
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Jun2018.txt
# ____________________________________________________________
#
# 22 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-18-010545/full-submission.txt
# found here 156
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-18-010545/full-submission.txt
# 0001564590-18-010545 172
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Mar2018.txt
# ____________________________________________________________
#
# 23 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-17-021032/full-submission.txt
# found here 157
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-17-021032/full-submission.txt
# 0001564590-17-021032 520
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Sep2017.txt
# ____________________________________________________________
#
# 24 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-17-015153/full-submission.txt
# found here 158
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-17-015153/full-submission.txt
# 0001564590-17-015153 270
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Jun2017.txt
# ____________________________________________________________
#
# 25 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-17-008260/full-submission.txt
# found here 159
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-17-008260/full-submission.txt
# 0001564590-17-008260 228
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Mar2017.txt
# ____________________________________________________________
#
# 26 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-16-027067/full-submission.txt
# found here 160
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-16-027067/full-submission.txt
# 0001564590-16-027067 212
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Sep2016.txt
# ____________________________________________________________
#
# 27 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-16-022552/full-submission.txt
# found here 161
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-16-022552/full-submission.txt
# 0001564590-16-022552 226
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Jun2016.txt
# ____________________________________________________________
#
# 28 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/TXN/10-Q/0001564590-16-017570/full-submission.txt
# found here 162
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/TXN/10-Q/0001564590-16-017570/full-submission.txt
# 0001564590-16-017570 188
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/TXN_0001564590_10-Q_Mar2016.txt
# ____________________________________________________________
#
# 29 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/ULTA/10-Q/0001193125-17-191202/full-submission.txt
# found here 163
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/ULTA/10-Q/0001193125-17-191202/full-submission.txt
# 0001193125-17-191202 54
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/ULTA_0001193125_10-Q_Apr2017.txt
# ____________________________________________________________
#
# 30 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XEL/10-Q/0000072903-20-000055/full-submission.txt
# found here 164
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XEL/10-Q/0000072903-20-000055/full-submission.txt
# 0000072903-20-000055 77
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XEL_0000072903_10-Q_Jun2020.txt
# ____________________________________________________________
#
#
# 31 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XEL/10-Q/0000072903-20-000022/full-submission.txt
# found here 165
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XEL/10-Q/0000072903-20-000022/full-submission.txt
# 0000072903-20-000022 87
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XEL_0000072903_10-Q_Mar2020.txt
# ____________________________________________________________
#
# 32 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000074/full-submission.txt
# found here 166
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XEL/10-Q/0000072903-19-000074/full-submission.txt
# 0000072903-19-000074 83
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XEL_0000072903_10-Q_Sep2019.txt
# ____________________________________________________________
#
# 33 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000047/full-submission.txt
# found here 167
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XEL/10-Q/0000072903-19-000047/full-submission.txt
# 0000072903-19-000047 77
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XEL_0000072903_10-Q_Jun2019.txt
# ____________________________________________________________
#
# 34 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XEL/10-Q/0000072903-19-000019/full-submission.txt
# found here 168
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XEL/10-Q/0000072903-19-000019/full-submission.txt
# 0000072903-19-000019 64
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XEL_0000072903_10-Q_Mar2019.txt
# ____________________________________________________________
#
# 35 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000042/full-submission.txt
# found here 169
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-18-000042/full-submission.txt
# 0000818479-18-000042 557
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Sep2018.txt
# ____________________________________________________________
#
# 36 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000035/full-submission.txt
# found here 170
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-18-000035/full-submission.txt
# 0000818479-18-000035 581
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Jun2018.txt
# ____________________________________________________________
#
# 37 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-18-000019/full-submission.txt
# found here 171
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-18-000019/full-submission.txt
# 0000818479-18-000019 349
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Mar2018.txt
# ____________________________________________________________
#
# 38 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000031/full-submission.txt
# found here 172
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-17-000031/full-submission.txt
# 0000818479-17-000031 583
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Sep2017.txt
# ____________________________________________________________
#
# 39 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000025/full-submission.txt
# found here 173
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-17-000025/full-submission.txt
# 0000818479-17-000025 570
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Jun2017.txt
# ____________________________________________________________
#
# 40 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-17-000012/full-submission.txt
# found here 174
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-17-000012/full-submission.txt
# 0000818479-17-000012 358
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Mar2017.txt
# ____________________________________________________________
#
#
# 41 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-16-000086/full-submission.txt
# found here 175
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-16-000086/full-submission.txt
# 0000818479-16-000086 558
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Sep2016.txt
# ____________________________________________________________
#
# 42 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/XRAY/10-Q/0000818479-16-000081/full-submission.txt
# found here 176
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/XRAY/10-Q/0000818479-16-000081/full-submission.txt
# 0000818479-16-000081 555
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/XRAY_0000818479_10-Q_Jun2016.txt
# ____________________________________________________________
#
# 43 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000175/full-submission.txt
# found here 177
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/PTON/10-Q/0001639825-20-000175/full-submission.txt
# 0001639825-20-000175 328
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/PTON_0001639825_10-Q_Sep2020.txt
# ____________________________________________________________
#
# 44 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000068/full-submission.txt
# found here 178
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/PTON/10-Q/0001639825-20-000068/full-submission.txt
# 0001639825-20-000068 429
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/PTON_0001639825_10-Q_Mar2020.txt
# ____________________________________________________________
#
# 45 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/PTON/10-Q/0001639825-20-000011/full-submission.txt
# found here 179
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/PTON/10-Q/0001639825-20-000011/full-submission.txt
# 0001639825-20-000011 401
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/PTON_0001639825_10-Q_Dec2019.txt
# ____________________________________________________________
#
# 46 of 90 ------------------------------
# ticker, cik_10dig, filing_type, filing_qrtr, doc_reported_on, doc_year DONE
# ../data/sec-edgar-filings/PTON/10-Q/0001639825-19-000018/full-submission.txt
# found here 180
# FOUND IN FAILED FILES /home/jovyan/work/benu_work/needs_work2/PTON/10-Q/0001639825-19-000018/full-submission.txt
# 0001639825-19-000018 341
#
# Parsing finished, output saved in:
# ../data/2021-03-20_parsed_sec_filings_path/PTON_0001639825_10-Q_Sep2019.txt
# ____________________________________________________________

# %%
#


soup.text
# Out:
# '0.0);text-align:right;vertical-align:bottom;padding-left:1pt;padding-right:1pt;">Alphabet Inc.ITEM 2.MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS OF OPERATIONSPlease read the following discussion and analysis of our financial condition and results of operations together with our consolidated financial statements and related notes included under Part I, Item\xa01 of this Quarterly Report on Form 10-Q.Executive Overview of ResultsBelow are our key financial results for the three months ended June 30, 2020 (consolidated unless otherwise noted):•Revenues were $38.3 billion, a decrease of 2% year over year, constant currency revenues were flat year over year.•Google segment revenues were $38.0 billion, a decrease of 2% year over year, and Other Bets revenues were $148 million, a decrease of 9% year over year.•Revenues from the United States, EMEA, APAC, and Other Americas were $18.0 billion, $11.4 billion, $6.9 billion, and $1.8 billion, respectively.•Cost of revenues was $18.6 billion, consisting of TAC of $6.7 billion and other cost of revenues of $11.9 billion. TAC as a percentage of advertising revenues ("TAC rate") was 22.4%. •Operating expenses (excluding cost of revenues) were $13.4 billion. •Income from operations was $6.4 billion.•Other income (expense), net, was a gain of $1.9 billion.•Effective tax rate was 15.9%.•Net income was $7.0 billion with diluted net income per share of $10.13.•Operating cash flow was $14.0 billion.•Capital expenditures were $5.4\xa0billion.•Number of employees was 127,498 as of June\xa030, 2020. The majority of new hires during the quarter were engineers and product managers. By product area, the largest headcount additions were in Google Cloud and Search.The Impact of COVID-19 on our Results and OperationsIn late 2019, an outbreak of COVID-19 emerged and by March 11, 2020 was declared a global pandemic by The World Health Organization. Across the United States and the world, governments and municipalities instituted measures in an effort to control the spread of COVID-19, including quarantines, shelter-in-place orders, school closings, travel restrictions and the closure of non-essential businesses. The macroeconomic impacts of COVID-19 are significant and continue to evolve, as exhibited by, among other things, a rise in unemployment, changes in consumer behavior, and market volatility. We began to observe the impact of COVID-19 on our financial results late in the quarter ended March 31, 2020.For the quarter ended June 30, 2020, our advertising revenues declined compared to the prior year due to the continued impacts of COVID-19 and the related reductions in global economic activity. During the course of the quarter, we observed a gradual return in user search activity to more commercial topics, followed by increased spending by our advertisers. The decline in advertising revenues was partially offset by continued growth in Google Cloud and other non-advertising revenues.We continue to assess the realized and potential credit deterioration of our customers due to changes in the macroeconomic environment, which has been reflected in an increase in our allowance for credit losses for accounts receivable. We experienced pressure on our margins as many of our expenses are less variable in nature and/or may not correlate to changes in revenues, including costs associated with our data centers and facilities as well as employee compensation. In addition, market volatility has contributed to fluctuations in the valuation of our equity investments, and for the quarter ended June 30, 2020 we recognized net gains on our equity investments as compared to net losses in the quarter ended March 30, 2020.While we continued to make investments in land and buildings for data centers, offices and information technology infrastructure, we have slowed the pace of our investments, primarily as it relates to office facilities.34Looking ahead, the impact of COVID-19 on our business conti ...

# %%
def parser_custom(TenKtext):
    # Clean newly extracted text
    TenKItem7 = TenKItem7.strip() # Remove starting/ending white spaces
    TenKItem7 = TenKItem7.replace('\n', ' ') # Replace \n (new line) with space
    TenKItem7 = TenKItem7.replace('\r', '') # Replace \r (carriage returns-if you're on windows) with space
    TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space
    TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space

    while '  ' in TenKItem7:
        TenKItem7 = TenKItem7.replace('  ', ' ') # Remove extra spaces

    # Print first 500 characters of newly extracted text
    #print(TenKItem7[:500])
    TenKItem7 = TenKItem7.replace(u'/xa0', u' ') # 
    return TenKItem7

# %%
'''discards = []
def parser_custom(TenKtext):
    
    matches = re.compile(r'(item\s(7[\.\s]|8[\.\s])|'
                         'discussion\sand\sanalysis\sof\s(consolidated\sfinancial|financial)\scondition|'
                         '(consolidated\sfinancial|financial)\sstatements\sand\ssupplementary\sdata)', re.IGNORECASE)

    matches_array = pd.DataFrame([(match.group(), match.start()) for match in matches.finditer(TenKtext)])
    print(len(matches_array), matches_array.shape, matches_array.columns)
    # Set columns in the dataframe
    matches_array.columns = ['SearchTerm', 'Start']
    print('hi', len(matches_array), matches_array.shape, matches_array.columns)
    # Get the number of rows in the dataframe
    Rows = matches_array['SearchTerm'].count()
    
    # Create a new column in 'matches_array' called 'Selection' and add adjacent 'SearchTerm' (i and i+1 rows) text concatenated
    count = 0 # Counter to help with row location and iteration
    while count < (Rows-1): # Can only iterate to the second last row
        matches_array.at[count,'Selection'] = (matches_array.iloc[count,0] + matches_array.iloc[count+1,0]).lower() # Convert to lower case
        count += 1

    # Set up 'Item 7/8 Search Pattern' regex patterns
    matches_item7 = re.compile(r'(item\s7\.discussion\s[a-z]*)')
    matches_item8 = re.compile(r'(item\s8\.(consolidated\sfinancial|financial)\s[a-z]*)')

    # Lists to store the locations of Item 7/8 Search Pattern matches
    Start_Loc = []
    End_Loc = []

    # Find and store the locations of Item 7/8 Search Pattern matches
    count = 0 # Set up counter

    while count < (Rows-1): # Can only iterate to the second last row

        # Match Item 7 Search Pattern
        if re.match(matches_item7, matches_array.at[count,'Selection']):
            # Column 1 = 'Start' column in 'matches_array'
            
            Start_Loc.append(matches_array.iloc[count,1]) # Store in list => Item 7 will be the starting location (column '1' = 'Start' column)

        # Match Item 8 Search Pattern
        if re.match(matches_item8, matches_array.at[count,'Selection']):
            End_Loc.append(matches_array.iloc[count,1])

        count += 1
    
    print(Start_Loc, End_Loc)
    input()
    if len(Start_Loc)==len(End_Loc)==0:
        return False
    if len(Start_Loc)==len(End_Loc)==1:
        print(Start_Loc, End_Loc)
    

        # Extract section of text and store in 'TenKItem7'
        TenKItem7 = TenKtext[Start_Loc[0]:End_Loc[0]]
        #print(len(TenKItem7))
    elif len(Start_Loc)!=len(End_Loc):
        TenKItem7 = TenKtext[Start_Loc[0]:End_Loc[-1]]
    else :
        print(Start_Loc, End_Loc)
        # Extract section of text and store in 'TenKItem7'
        TenKItem7 = TenKtext[Start_Loc[1]:End_Loc[1]]
        #print(len(TenKItem7))
        
    # Clean newly extracted text
    TenKItem7 = TenKItem7.strip() # Remove starting/ending white spaces
    TenKItem7 = TenKItem7.replace('\n', ' ') # Replace \n (new line) with space
    TenKItem7 = TenKItem7.replace('\r', '') # Replace \r (carriage returns-if you're on windows) with space
    TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space
    TenKItem7 = TenKItem7.replace(' ', ' ') # Replace " " (a special character for space in HTML) with space

    while '  ' in TenKItem7:
        TenKItem7 = TenKItem7.replace('  ', ' ') # Remove extra spaces

    # Print first 500 characters of newly extracted text
    #print(TenKItem7[:500])
    TenKItem7 = TenKItem7.replace(u'/xa0', u' ') # 
    return TenKItem7'''
